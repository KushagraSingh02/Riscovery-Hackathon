# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
import fuzz

# %%
df=pd.read_excel("master.xlsx")
df.head()
# Out:
#          make    model     variant fuel_type    cc  seating_capacity  \
# 0  ALFA ROMEO  156 GTA         STD    Petrol  3179                 5
# 1  ALFA ROMEO  VINTAGE       ROMEO    Petrol  1100                 5
# 2  ALFA ROMEO  VINTAGE  ALFA ROMEO    Petrol  1750                 5
# 3  ALFA ROMEO  VINTAGE  ALFA ROMEO    Petrol  1570                 5
# 4  ALFA ROMEO  VINTAGE  ALFA ROMEO    Petrol  1110                 5
#
#        output
# 0  1110110101
# 1  1110110201
# 2  1110110202
# 3  1110110203
# 4  1110110204

# %%
#df.drop(df.iloc[:, 7:26], inplace=True, axis=1)
df.head()
# Out:
#          make    model     variant fuel_type    cc  seating_capacity  \
# 0  ALFA ROMEO  156 GTA         STD    Petrol  3179                 5
# 1  ALFA ROMEO  VINTAGE       ROMEO    Petrol  1100                 5
# 2  ALFA ROMEO  VINTAGE  ALFA ROMEO    Petrol  1750                 5
# 3  ALFA ROMEO  VINTAGE  ALFA ROMEO    Petrol  1570                 5
# 4  ALFA ROMEO  VINTAGE  ALFA ROMEO    Petrol  1110                 5
#
#        output
# 0  1110110101
# 1  1110110201
# 2  1110110202
# 3  1110110203
# 4  1110110204

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7678 entries, 0 to 7677
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   make              7678 non-null   object
#  1   model             7678 non-null   object
#  2   variant           7678 non-null   object
#  3   fuel_type         7678 non-null   object
#  4   cc                7678 non-null   int64
#  5   seating_capacity  7678 non-null   int64
#  6   output            7678 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 420.0+ KB

# %%
make_dic={}

make_num=df['make'].unique()
for i,y in enumerate(make_num):
    make_dic[y]=i
make_dic
# Out:
# {'ALFA ROMEO': 0,
#  'ASTON MARTIN': 1,
#  'AUDI': 2,
#  'BENTLEY': 3,
#  'BMW': 4,
#  'MINI': 5,
#  'CHEVROLET': 6,
#  'CHRYSLER': 7,
#  'DAEWOO': 8,
#  'DATSUN': 9,
#  'FERRARI': 10,
#  'FIAT': 11,
#  'FORCE': 12,
#  'FORD': 13,
#  'HINDUSTAN': 14,
#  'HONDA': 15,
#  'HUMMER': 16,
#  'HYUNDAI': 17,
#  'INFINITI': 18,
#  'JAGUAR': 19,
#  'LAMBORGHINI': 20,
#  'LAND ROVER': 21,
#  'Land Rover': 22,
#  'MAHINDRA AND MAHINDRA': 23,
#  'Mahindra And Mahindra': 24,
#  'MAHINDRA RENAULT': 25,
#  'MAHINDRA REVA': 26,
#  'MARUTI SUZUKI': 27,
#  'MASERATI': 28,
#  'MERCEDES-BENZ': 29,
#  'MITSUBISHI': 30,
#  'NISSAN MOTORS': 31,
#  'OPEL': 32,
#  'PORSCHE': 33,
#  'PREMIER': 34,
#  'RENAULT': 35,
#  'ROLLS ROYCE': 36,
#  'SKODA': 37,
#  'SSANGYONG': 38,
#  'TATA': 39,
#  'TOYOTA': 40,
#  'VOLKSWAGEN': 41,
#  'Volkswagen': 42,
#  'VOLVO': 43,
#  'ISUZU': 44,
#  'JEEP': 45,
#  'LEXUS': 46,
#  'WILLYS INDIA': 47,
#  'STANDARD HERALD': 48,
#  'BAJAJ': 49,
#  'CITROEN': 50,
#  'DODGE': 51,
# ...

# %%
df['make']=[make_dic[x] for x in df['make']]

# %%
df.head()
# Out:
#    make    model     variant fuel_type    cc  seating_capacity      output
# 0     0  156 GTA         STD    Petrol  3179                 5  1110110101
# 1     0  VINTAGE       ROMEO    Petrol  1100                 5  1110110201
# 2     0  VINTAGE  ALFA ROMEO    Petrol  1750                 5  1110110202
# 3     0  VINTAGE  ALFA ROMEO    Petrol  1570                 5  1110110203
# 4     0  VINTAGE  ALFA ROMEO    Petrol  1110                 5  1110110204

# %%
model_dic={}

model_num=df['model'].unique()
for i,y in enumerate(model_num):
    model_dic[y]=i
model_dic
# Out:
# {'156 GTA': 0,
#  'VINTAGE': 1,
#  'DB9': 2,
#  'DBS': 3,
#  'RAPIDE': 4,
#  'VANTAGE V8': 5,
#  'VIRAGE': 6,
#  'DB11': 7,
#  'VANQUISH': 8,
#  'One 77': 9,
#  'DBX': 10,
#  'A3': 11,
#  'A4': 12,
#  'A6': 13,
#  'A8': 14,
#  'Q3': 15,
#  'Q5': 16,
#  'Q7': 17,
#  'R8': 18,
#  'RS 6': 19,
#  'RS 7': 20,
#  'S5 SPORT BACK': 21,
#  'TT': 22,
#  'A7': 23,
#  'C7': 24,
#  'RS 5': 25,
#  'S4': 26,
#  'S6': 27,
#  'A5': 28,
#  'Q8': 29,
#  'Q2': 30,
#  'E TRON': 31,
#  'ARANGE': 32,
#  'AZURE T': 33,
#  'CONTINENTAL FLYING SPUR': 34,
#  'CONTINENTAL GT': 35,
#  'CONTINENTAL SUPERSPORTS': 36,
#  'MULSANNE': 37,
#  'AZURE': 38,
#  'CONTINENTAL': 39,
#  'BROOKLANDS': 40,
#  'TURBO R': 41,
#  'BENTAYGA': 42,
#  '1 SERIES': 43,
#  '3 SERIES': 44,
#  '5 SERIES': 45,
#  '6 SERIES CONVERTIBLE': 46,
#  '6 SERIES COUPE': 47,
#  '6 SERIES': 48,
#  '7 SERIES': 49,
#  'GRAN TURISMO': 50,
#  'Gran Turismo': 51,
#  'i8': 52,
#  'M MODELS': 53,
#  'M3': 54,
#  'M4': 55,
#  'M5': 56,
#  'M6': 57,
# ...

# %%
df['model']=[model_dic[x] for x in df['model']]

# %%
df.head()
# Out:
#    make  model     variant fuel_type    cc  seating_capacity      output
# 0     0      0         STD    Petrol  3179                 5  1110110101
# 1     0      1       ROMEO    Petrol  1100                 5  1110110201
# 2     0      1  ALFA ROMEO    Petrol  1750                 5  1110110202
# 3     0      1  ALFA ROMEO    Petrol  1570                 5  1110110203
# 4     0      1  ALFA ROMEO    Petrol  1110                 5  1110110204

# %%
var_dic={}

var_num=df['variant'].unique()
for i,y in enumerate(var_num):
    var_dic[y]=i
var_dic
# Out:
# {'STD': 0,
#  'ROMEO': 1,
#  'ALFA ROMEO': 2,
#  'Coupe': 3,
#  'Coupe 2STR': 4,
#  '6.0 RHD': 5,
#  '6.0 RHD Touchtronic': 6,
#  'S Coupe Sportshift': 7,
#  '6.0 V12 Volante': 8,
#  'V8 Coupe': 9,
#  'V12': 10,
#  'AUSTIN TEN': 11,
#  '2020': 12,
#  '35 TDI Premium Plus': 13,
#  '35 TDI Technology': 14,
#  '35 TFSI Premium Plus': 15,
#  '35 TFSI Technology': 16,
#  '35 TDI Attraction': 17,
#  '35 TDI Cabriolet': 18,
#  '35 TDI Limousine': 19,
#  '35 TDI Premium': 20,
#  '35TDI Premium+ with Sunroof': 21,
#  '35 TDI Premium with Sunroof': 22,
#  '35 TDI Technology Pack': 23,
#  '35TDI Technology Pack Sunroof': 24,
#  '35 TDI Technology Sunroof nav': 25,
#  '40 TFSI Cabriolet': 26,
#  '40 TFSI Cabriolet Full (O)': 27,
#  '40 TFSI Limousine': 28,
#  '40 TFSI Premium Plus': 29,
#  '40 TFSI Premium+ with Sunroof': 30,
#  '40TFSI Panoramic Glassroof': 31,
#  '1.4 TFSI Cabriolet': 32,
#  'V6 AT': 33,
#  '35 TFSI Cabriolet': 34,
#  '40 TFSI Premium': 35,
#  '30 TFSI Premium Plus': 36,
# ...

# %%
df['variant']=[var_dic[x] for x in df['variant']]

# %%
df.head()
# Out:
#    make  model  variant fuel_type    cc  seating_capacity      output
# 0     0      0        0    Petrol  3179                 5  1110110101
# 1     0      1        1    Petrol  1100                 5  1110110201
# 2     0      1        2    Petrol  1750                 5  1110110202
# 3     0      1        2    Petrol  1570                 5  1110110203
# 4     0      1        2    Petrol  1110                 5  1110110204

# %%
fuel_dic={}

fuel_num=df['fuel_type'].unique()
for i,y in enumerate(fuel_num):
    fuel_dic[y]=i
fuel_dic
# Out:
# {'Petrol': 0, 'Diesel': 1, 'Electric': 2, 'CNG': 3, 'LPG': 4}

# %%
df['fuel_type']=[fuel_dic[x] for x in df['fuel_type']]

# %%
df.head()
# Out:
#    make  model  variant  fuel_type    cc  seating_capacity      output
# 0     0      0        0          0  3179                 5  1110110101
# 1     0      1        1          0  1100                 5  1110110201
# 2     0      1        2          0  1750                 5  1110110202
# 3     0      1        2          0  1570                 5  1110110203
# 4     0      1        2          0  1110                 5  1110110204

# %%
cc_dic={}

cc_num=df['cc'].unique()
for i,y in enumerate(cc_num):
    cc_dic[y]=i
cc_dic
# Out:
# {3179: 0,
#  1100: 1,
#  1750: 2,
#  1570: 3,
#  1110: 4,
#  5935: 5,
#  4735: 6,
#  3880: 7,
#  5204: 8,
#  1000: 9,
#  7312: 10,
#  3982: 11,
#  1968: 12,
#  1984: 13,
#  1798: 14,
#  1395: 15,
#  1781: 16,
#  2967: 17,
#  3197: 18,
#  1997: 19,
#  2698: 20,
#  2773: 21,
#  2976: 22,
#  2995: 23,
#  3132: 24,
#  4134: 25,
#  3993: 26,
#  6299: 27,
#  4163: 28,
#  5998: 29,
#  6300: 30,
#  3597: 31,
#  3996: 32,
#  3189: 33,
#  2894: 34,
#  2189: 35,
#  1: 36,
#  6761: 37,
#  6000: 38,
#  6752: 39,
#  6750: 40,
#  2000: 41,
#  1598: 42,
#  4500: 43,
#  4000: 44,
#  1850: 45,
#  4257: 46,
#  4275: 47,
#  5950: 48,
#  1995: 49,
#  2993: 50,
#  1895: 51,
#  1596: 52,
#  2497: 53,
#  2996: 54,
#  1998: 55,
#  2998: 56,
#  2793: 57,
#  2979: 58,
#  4398: 59,
#  4799: 60,
#  4395: 61,
#  5972: 62,
#  3600: 63,
#  4244: 64,
#  4691: 65,
#  1499: 66,
#  4999: 67,
#  3999: 68,
#  2987: 69,
#  2171: 70,
#  2997: 71,
#  2900: 72,
#  1496: 73,
#  1275: 74,
#  1399: 75,
#  1150: 76,
#  936: 77,
# ...

# %%
df['cc']=[cc_dic[x] for x in df['cc']]

# %%
df
# Out:
#       make  model  variant  fuel_type   cc  seating_capacity      output
# 0        0      0        0          0    0                 5  1110110101
# 1        0      1        1          0    1                 5  1110110201
# 2        0      1        2          0    2                 5  1110110202
# 3        0      1        2          0    3                 5  1110110203
# 4        0      1        2          0    4                 5  1110110204
# ...    ...    ...      ...        ...  ...               ...         ...
# 7673   153    620     6018          1   86                 5  1125800101
# 7674   154      1      483          1  608                 5  1125900101
# 7675   155      1     6019          0  204                 2  1126000101
# 7676   156      1     6020          0   89                 2  1126100101
# 7677    40    540     6021          1  287                 5  1113913204
#
# [7678 rows x 7 columns]

# %%
sc_dic={}

sc_num=df['seating_capacity'].unique()
for i,y in enumerate(sc_num):
    sc_dic[y]=i
sc_dic
# Out:
# {5: 0, 4: 1, 2: 2, 7: 3, 6: 4, 8: 5, 10: 6, 9: 7, 12: 8, 13: 9, 14: 10, 1: 11}

# %%
df['seating_capacity']=[sc_dic[x] for x in df['seating_capacity']]

# %%
df
# Out:
#       make  model  variant  fuel_type   cc  seating_capacity      output
# 0        0      0        0          0    0                 0  1110110101
# 1        0      1        1          0    1                 0  1110110201
# 2        0      1        2          0    2                 0  1110110202
# 3        0      1        2          0    3                 0  1110110203
# 4        0      1        2          0    4                 0  1110110204
# ...    ...    ...      ...        ...  ...               ...         ...
# 7673   153    620     6018          1   86                 0  1125800101
# 7674   154      1      483          1  608                 0  1125900101
# 7675   155      1     6019          0  204                 2  1126000101
# 7676   156      1     6020          0   89                 2  1126100101
# 7677    40    540     6021          1  287                 0  1113913204
#
# [7678 rows x 7 columns]

# %%
inputs=['make','model','variant','cc','seating_capacity','fuel_type']
x = df[inputs] # Features
y = df.local_output # Target variable
x
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [31], line 3
#       1 inputs=['make','model','variant','cc','seating_capacity','fuel_type']
#       2 x = df[inputs] # Features
# ----> 3 y = df.local_output # Target variable
#       4 x
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'local_output'

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=42) # 70% training and 30% test
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [37], line 1
# ----> 1 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=42)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/model_selection/_split.py:2445, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2442 if n_arrays == 0:
#    2443     raise ValueError("At least one array required as input")
# -> 2445 arrays = indexable(*arrays)
#    2447 n_samples = _num_samples(arrays[0])
#    2448 n_train, n_test = _validate_shuffle_split(
#    2449     n_samples, test_size, train_size, default_test_size=0.25
#    2450 )
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:433, in indexable(*iterables)
#     414 """Make arrays indexable for cross-validation.
#     415
# ...

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(x_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [38], line 5
#       2 clf = DecisionTreeClassifier()
#       4 # Train Decision Tree Classifer
# ----> 5 clf = clf.fit(x_train,y_train)
#       7 #Predict the response for test dataset
#       8 y_pred = clf.predict(x_test)
#
# NameError: name 'x_train' is not defined

# %%
print(clf.predict([[1,1,1,1,0,1]]))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In [39], line 1
# ----> 1 print(clf.predict([[1,1,1,1,0,1]]))
#
# File ~/.local/lib/python3.10/site-packages/sklearn/tree/_classes.py:504, in BaseDecisionTree.predict(self, X, check_input)
#     481 def predict(self, X, check_input=True):
#     482     """Predict class or regression value for X.
#     483
#     484     For a classification model, the predicted class for each sample in X is
#    (...)
#     502         The predicted classes, or the predict values.
#     503     """
# --> 504     check_is_fitted(self)
#     505     X = self._validate_X_predict(X, check_input)
#     506     proba = self.tree_.predict(X)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:1345, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1340     fitted = [
# ...

# %%
df_train=pd.read_excel("train.xlsx")
df_test=pd.read_csv("test_mine.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [40], line 2
#       1 df_train=pd.read_excel("train.xlsx")
# ----> 2 df_test=pd.read_csv("test_mine.csv")
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df_train
# Out:
#                  make      model                       variant    cc  \
# 0               HONDA       CR-V                        2.4 MT  2354
# 1               HONDA       CR-V                        2.4 MT  2354
# 2          VOLKSWAGEN       AMEO  1.5L TDI MT COMFORTLINE PLUS  1498
# 3                FORD       FIGO    1.2 TITANIUM SPORTS PETROL  1196
# 4         LAMBORGHINI  AVENTADOR                    S LP 740-4  6498
# ...               ...        ...                           ...   ...
# 5732  TATA MOTORS LTD      TIGOR                        XZ CNG  1199
# 5733  TATA MOTORS LTD      TIGOR                REVOTRON XZ(O)  1199
# 5734  TATA MOTORS LTD      TIGOR                   REVOTRON XT  1199
# 5735             FORD       IKON                      1.3 IRIS  1299
# 5736        MAHINDRA.    KUV 100                TRIP 5 STR CNG  1198
#
#       seating_capacity fuel_type  local_output
# 0                    5    PETROL         12623
# ...

# %%
df_train.drop(df_train.iloc[:, 7:26], inplace=True, axis=1)

# %%
df_train
# Out:
#                  make      model                       variant    cc  \
# 0               HONDA       CR-V                        2.4 MT  2354
# 1               HONDA       CR-V                        2.4 MT  2354
# 2          VOLKSWAGEN       AMEO  1.5L TDI MT COMFORTLINE PLUS  1498
# 3                FORD       FIGO    1.2 TITANIUM SPORTS PETROL  1196
# 4         LAMBORGHINI  AVENTADOR                    S LP 740-4  6498
# ...               ...        ...                           ...   ...
# 5732  TATA MOTORS LTD      TIGOR                        XZ CNG  1199
# 5733  TATA MOTORS LTD      TIGOR                REVOTRON XZ(O)  1199
# 5734  TATA MOTORS LTD      TIGOR                   REVOTRON XT  1199
# 5735             FORD       IKON                      1.3 IRIS  1299
# 5736        MAHINDRA.    KUV 100                TRIP 5 STR CNG  1198
#
#       seating_capacity fuel_type  local_output
# 0                    5    PETROL         12623
# ...

# %%
df_train=df_train.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [36], line 1
# ----> 1 df_train=df_train.drop_duplicates()
#
# NameError: name 'df_train' is not defined

# %%
simi=0
max1=0
output=[]
index1=0
df_train.set_index("local_output", inplace = True)
for i in df_test.index:
    max1=0
    l=[]
    lo_ou=df_test['local_output'][i]
    result=df_train.loc[lo_ou]
    for _ in range(6):
        l.append(result[_])
    for j in df.index:
        train_str="".join(l)
        list_master=[df['make'][j],df['model'][j],df['variant'][j],df['cc'][j],df['seating_capacity'][j],df['fuel_type'][j]]
        master_str=" ".join(list_master)
        #print(train_str)
        #print(master_str)
        simi=fuzz.token_set_ratio(master_str, train_str)
        if(simi>max1):
            max1=simi
            index1=j
            print(index1)
    #print(output)
    print(df['output'][index1])
    #output.append(df['output'][index1])
    simi=0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [35], line 1
# ----> 1 df_train['local_output'] = df_train['local_output'].astype("int64")
#       2 # Setting the index of the dataframe to the Date column so that time series plots could be shown
#       3 #df_train = df_train.set_index('local_output')
#       4 df_train
#
# NameError: name 'df_train' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [34], line 1
# ----> 1 df_train.set_index("local_output", inplace = True)
#       2 for i in df_test.index:
#       3     l=[]
#
# NameError: name 'df_train' is not defined
